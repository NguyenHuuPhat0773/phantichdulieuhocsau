# %% [markdown]
# ### Câu 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Dữ liệu mẫu
data = {
    'Name': ['Mr. Harris', 'Mrs. Bradley', 'Miss. Laina ', 'Mrs. Heath', 'Mr. William', 'Mr. James', 'Mr. Timothy ', 'Mrs. Oscar', 'Mrs. Nicholas', 'Miss. Marguerite','Mr. William','Miss. Hulda','Mr. Lawrence','Mr. Wilam '],
    'Age': [32,45,22,52,48,21,28,69,58,21,48,33,25,70],
    'Height': [1.80,1.61,1.78,1.74,1.55,1.9,1.61,1.40,1.92,1.77,1.55,1.85,1.64,1.77],
    'Weight':[90,87,64,70,100,106,82,55,77,60,100,109,80,66],
}

df = pd.DataFrame(data)
df
# Out:
#                 Name  Age  Height  Weight
# 0         Mr. Harris   32    1.80      90
# 1       Mrs. Bradley   45    1.61      87
# 2       Miss. Laina    22    1.78      64
# 3         Mrs. Heath   52    1.74      70
# 4        Mr. William   48    1.55     100
# 5          Mr. James   21    1.90     106
# 6       Mr. Timothy    28    1.61      82
# 7         Mrs. Oscar   69    1.40      55
# 8      Mrs. Nicholas   58    1.92      77
# 9   Miss. Marguerite   21    1.77      60
# 10       Mr. William   48    1.55     100
# 11       Miss. Hulda   33    1.85     109
# 12      Mr. Lawrence   25    1.64      80
# 13        Mr. Wilam    70    1.77      66

# %% [markdown]
# ### Câu 2

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    14 non-null     object
#  1   Age     14 non-null     int64
#  2   Height  14 non-null     float64
#  3   Weight  14 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 576.0+ bytes
# None

# %% [markdown]
# ### Câu 3

# %%
avg_age = df['Age'].mean()
print("Giá trị trung bình của Age:", avg_age)
# Out:
# Giá trị trung bình của Age: 40.857142857142854

# %% [markdown]
# ### Câu 4

# %%
grouped_Height = df.groupby('Height')['Weight'].mean()
print(grouped_Height)
# Out:
# Height
# 1.40     55.0
# 1.55    100.0
# 1.61     84.5
# 1.64     80.0
# 1.74     70.0
# 1.77     63.0
# 1.78     64.0
# 1.80     90.0
# 1.85    109.0
# 1.90    106.0
# 1.92     77.0
# Name: Weight, dtype: float64

# %% [markdown]
# ### Câu 5

# %%
sorted_df = df.sort_values(by='Weight', ascending=True)
print(sorted_df)
# Out:
#                 Name  Age  Height  Weight
# 7         Mrs. Oscar   69    1.40      55
# 9   Miss. Marguerite   21    1.77      60
# 2       Miss. Laina    22    1.78      64
# 13        Mr. Wilam    70    1.77      66
# 3         Mrs. Heath   52    1.74      70
# 8      Mrs. Nicholas   58    1.92      77
# 12      Mr. Lawrence   25    1.64      80
# 6       Mr. Timothy    28    1.61      82
# 1       Mrs. Bradley   45    1.61      87
# 0         Mr. Harris   32    1.80      90
# 4        Mr. William   48    1.55     100
# 10       Mr. William   48    1.55     100
# 5          Mr. James   21    1.90     106
# 11       Miss. Hulda   33    1.85     109

# %% [markdown]
# ### Câu 6

# %%
plt.bar(df['Name'], df['Age'])
plt.xlabel('Name')
plt.ylabel('Age')
plt.title('Biểu đồ cột Age')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Câu 7

# %%
plt.scatter(df['Age'], df['Height'])
plt.xlabel('Age')
plt.ylabel('Height')
plt.title('Biểu đồ phân tán Age vs Height')
plt.show()

# %% [markdown]
# ### Câu 8

# %%
df['Weight'].plot(kind='line')
plt.title("Biểu đồ đường cho Weight")
plt.xlabel("Index")
plt.ylabel("Weight")
plt.show()

# %% [markdown]
# ### Câu 9

# %%
df['Height'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Biểu đồ tròn cho Height")
plt.show()

# %% [markdown]
# ### Câu 10

# %%
plt.scatter(df['Weight'], df['Age'])
plt.xlabel('Weight')
plt.ylabel('Age')
plt.title('Biểu đồ phân tán Height vs Age')
plt.show()

# %% [markdown]
# ### Câu 11

# %%
has_nan = df.isna().any().any()
print(f"Has NaN values: {has_nan}")
# Out:
# Has NaN values: False

# %% [markdown]
# ### Câu 12

# %%
df.drop_duplicates(subset='Name', keep='first', inplace=True)
print(df)
# Out:
#                 Name  Age  Height  Weight
# 0         Mr. Harris   32    1.80      90
# 1       Mrs. Bradley   45    1.61      87
# 2       Miss. Laina    22    1.78      64
# 3         Mrs. Heath   52    1.74      70
# 4        Mr. William   48    1.55     100
# 5          Mr. James   21    1.90     106
# 6       Mr. Timothy    28    1.61      82
# 7         Mrs. Oscar   69    1.40      55
# 8      Mrs. Nicholas   58    1.92      77
# 9   Miss. Marguerite   21    1.77      60
# 11       Miss. Hulda   33    1.85     109
# 12      Mr. Lawrence   25    1.64      80
# 13        Mr. Wilam    70    1.77      66

# %% [markdown]
# ### Câu 13

# %%
df.loc[df['Age'] > 40, 'Age'] = df['Age'].mean()
print(df)
# Out:
#                 Name        Age  Height  Weight
# 0         Mr. Harris  32.000000    1.80      90
# 1       Mrs. Bradley  40.307692    1.61      87
# 2       Miss. Laina   22.000000    1.78      64
# 3         Mrs. Heath  40.307692    1.74      70
# 4        Mr. William  40.307692    1.55     100
# 5          Mr. James  21.000000    1.90     106
# 6       Mr. Timothy   28.000000    1.61      82
# 7         Mrs. Oscar  40.307692    1.40      55
# 8      Mrs. Nicholas  40.307692    1.92      77
# 9   Miss. Marguerite  21.000000    1.77      60
# 11       Miss. Hulda  33.000000    1.85     109
# 12      Mr. Lawrence  25.000000    1.64      80
# 13        Mr. Wilam   40.307692    1.77      66

# %% [markdown]
# ### Câu 14

# %%
df['cs_BMI'] = df['Weight'] / (df['Height'] ** 2)
print(df)
# Out:
#                 Name        Age  Height  Weight     cs_BMI
# 0         Mr. Harris  32.000000    1.80      90  27.777778
# 1       Mrs. Bradley  40.307692    1.61      87  33.563520
# 2       Miss. Laina   22.000000    1.78      64  20.199470
# 3         Mrs. Heath  40.307692    1.74      70  23.120624
# 4        Mr. William  40.307692    1.55     100  41.623309
# 5          Mr. James  21.000000    1.90     106  29.362881
# 6       Mr. Timothy   28.000000    1.61      82  31.634582
# 7         Mrs. Oscar  40.307692    1.40      55  28.061224
# 8      Mrs. Nicholas  40.307692    1.92      77  20.887587
# 9   Miss. Marguerite  21.000000    1.77      60  19.151585
# 11       Miss. Hulda  33.000000    1.85     109  31.848064
# 12      Mr. Lawrence  25.000000    1.64      80  29.744200
# 13        Mr. Wilam   40.307692    1.77      66  21.066743

# %% [markdown]
# ### Câu 15

# %%
def phan_loai_bmi(bmi):
    if bmi < 18.5:
        return 0  # Thiếu cân
    elif 18.5 <= bmi < 23:
        return 1  # Bình thường
    elif 23 <= bmi < 25:
        return 2  # Thừa cân
    else:
        return 3  # Béo phì

df['Phan_Loai'] = df['cs_BMI'].apply(phan_loai_bmi)
print(df)
# Out:
#                 Name        Age  Height  Weight     cs_BMI  Phan_Loai
# 0         Mr. Harris  32.000000    1.80      90  27.777778          3
# 1       Mrs. Bradley  40.307692    1.61      87  33.563520          3
# 2       Miss. Laina   22.000000    1.78      64  20.199470          1
# 3         Mrs. Heath  40.307692    1.74      70  23.120624          2
# 4        Mr. William  40.307692    1.55     100  41.623309          3
# 5          Mr. James  21.000000    1.90     106  29.362881          3
# 6       Mr. Timothy   28.000000    1.61      82  31.634582          3
# 7         Mrs. Oscar  40.307692    1.40      55  28.061224          3
# 8      Mrs. Nicholas  40.307692    1.92      77  20.887587          1
# 9   Miss. Marguerite  21.000000    1.77      60  19.151585          1
# 11       Miss. Hulda  33.000000    1.85     109  31.848064          3
# 12      Mr. Lawrence  25.000000    1.64      80  29.744200          3
# ...

# %% [markdown]
# ### Câu 16

# %%
df['cs_BMI'] = (df['cs_BMI'] - df['cs_BMI'].min()) / (df['cs_BMI'].max() - df['cs_BMI'].min())
print(df)
# Out:
#                 Name        Age  Height  Weight    cs_BMI  Phan_Loai
# 0         Mr. Harris  32.000000    1.80      90  0.383869          3
# 1       Mrs. Bradley  40.307692    1.61      87  0.641336          3
# 2       Miss. Laina   22.000000    1.78      64  0.046631          1
# 3         Mrs. Heath  40.307692    1.74      70  0.176624          2
# 4        Mr. William  40.307692    1.55     100  1.000000          3
# 5          Mr. James  21.000000    1.90     106  0.454406          3
# 6       Mr. Timothy   28.000000    1.61      82  0.555498          3
# 7         Mrs. Oscar  40.307692    1.40      55  0.396482          3
# 8      Mrs. Nicholas  40.307692    1.92      77  0.077253          1
# 9   Miss. Marguerite  21.000000    1.77      60  0.000000          1
# 11       Miss. Hulda  33.000000    1.85     109  0.564998          3
# 12      Mr. Lawrence  25.000000    1.64      80  0.471375          3
# 13        Mr. Wilam   40.307692    1.77      66  0.085225          1

# %% [markdown]
# ### Câu 17

# %%
def get_GT(name):
    if 'Mr.' in name:
        return 'male'
    elif 'Mrs.' in name or 'Miss.' in name:
        return 'female'
    else:
        return None

df['GT'] = df['Name'].apply(get_GT)
df['Name'] = df['Name'].str.replace('Mr.|Mrs.|Miss.', '', regex=True).str.strip()
print(df)
# Out:
#           Name        Age  Height  Weight    cs_BMI  Phan_Loai      GT
# 0       Harris  32.000000    1.80      90  0.383869          3    male
# 1    . Bradley  40.307692    1.61      87  0.641336          3  female
# 2        Laina  22.000000    1.78      64  0.046631          1  female
# 3      . Heath  40.307692    1.74      70  0.176624          2  female
# 4      William  40.307692    1.55     100  1.000000          3    male
# 5        James  21.000000    1.90     106  0.454406          3    male
# 6      Timothy  28.000000    1.61      82  0.555498          3    male
# 7      . Oscar  40.307692    1.40      55  0.396482          3  female
# 8   . Nicholas  40.307692    1.92      77  0.077253          1  female
# 9   Marguerite  21.000000    1.77      60  0.000000          1  female
# 11       Hulda  33.000000    1.85     109  0.564998          3  female
# 12    Lawrence  25.000000    1.64      80  0.471375          3    male
# ...

# %% [markdown]
# ### Câu 18

# %%
GT_counts = df['GT'].value_counts()
plt.pie(GT_counts, labels=GT_counts.index, autopct='%1.1f%%')
plt.title('Biểu đồ tròn cho GT')
plt.show()

# %% [markdown]
# ### Câu 19

# %%
female_data = df[df['GT'] == 'female']['Phan_Loai'].value_counts()
plt.bar(female_data.index, female_data.values)
plt.xticks([0, 1, 2, 3], ['Thiếu cân', 'Bình thường', 'Thừa cân', 'Béo phì'])
plt.xlabel('Phân loại BMI')
plt.ylabel('Số lượng')
plt.title('Phân loại BMI của người nữ')
plt.show()

# %% [markdown]
# ### Câu 20

# %%
df.to_csv('BKT_2174802010834_NguyenHuuPhat.csv', index=False)
